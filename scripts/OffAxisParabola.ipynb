# %% [markdown]
# if not yet available some libraries have to be installed :<br>
# - gmsh (best installed globally through package management system)
# - python3 -m pip install pygmsh --user
# - python3 -m pip install vtk --user

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import constants
from MeshedFields import *

# %%
mesh = MeshedField.CircularMesh(R=0.05, ratio=25.0, lcar=0.03)

print("%d points" % len(mesh.points))
print("%d triangles" % len(mesh.triangles))
# Out:
# 117108 points
# 230862 triangles

# %% [markdown]
# The shape of a off-axis parabola follows a curve $z = \frac{r^2}{2 r_{fok}}$. $r_{fok}$ is the focal length of the parabola which is the distance of the (parallel) incidence axis of the beam and the rotational symmetry axis of the parabola (the z-axis). The distance from the parabola vertex to the focus is $r_{fok}/2$.<br>
# We compute the parabolic shape in a local coordinate system centered at the intersection of the incidence axis with the shape. In this local coordinate system, the focus is placed at $[r_{fok},0,0]$ and the vertex of the parabola at $[r_{fok},0,r_{fok}/2]$. A parallel beam incident from $[0,0,-z]$ (propagating in z direction) is collected into the focus at $[r_{fok},0,0]$.

# %%
def parabola(p,rfok):
    """
    Move a point p along the z axis so that is lies on the surface
    of an off-axis parabola with focal length rfok.
    """
    x = rfok-p[0]
    y = p[1]
    r = np.sqrt(x*x+y*y)
    z = -(r*r/(2.0*rfok)-0.5*rfok)
    return np.array([p[0],p[1],z])

d = np.array([0.0, 0.0, 1.258])
pts = [parabola(p,0.1)+d for p in mesh.points]
para = MeshedField(pts, mesh.triangles)

# %%
para.BoundingBox()
# Out:
# ((-0.050000000000000003, 0.050000000000000003),
#  (-0.050000000000000003, 0.050000000000000003),
#  (1.1955, 1.2955000000000001))

# %% [markdown]
# We check the typical size of the triangles in x and z direction.<br>
# This has to be substantially smaller than the wavelength.
#
# It does not show as expected because due to the surface curvature triangles at some y displacement from the axis are distorted. That's OK because for every triangle only one field trace is recorded and only the average spacing matters.

# %%
def zsize(id):
    t = para.triangles[id]
    pts = [para.points[ip] for ip in t]
    z = [p[2] for p in pts]
    dz = np.max(z)-np.min(z)
    return dz

def ysize(id):
    t = para.triangles[id]
    pts = [para.points[ip] for ip in t]
    y = [p[1] for p in pts]
    dy = np.max(y)-np.min(y)
    return dy

dy = [ysize(id) for id in range(para.Np)]
print(np.average(dy))
dz = [zsize(id) for id in range(para.Np)]
print(np.average(dz))

plt.hist(dz, bins=np.linspace(0,0.0005,20))
# Out:
# 0.00135402686858
# 0.000296920589029
# (array([   200.,   7240.,  16062.,  15561.,  13473.,  12424.,  11925.,
#          11659.,  11279.,  11259.,  11129.,  10737.,  10685.,   9975.,
#           9361.,   9054.,   8698.,   7772.,   7162.]),
#  array([  0.00000000e+00,   2.63157895e-05,   5.26315789e-05,
#           7.89473684e-05,   1.05263158e-04,   1.31578947e-04,
#           1.57894737e-04,   1.84210526e-04,   2.10526316e-04,
#           2.36842105e-04,   2.63157895e-04,   2.89473684e-04,
#           3.15789474e-04,   3.42105263e-04,   3.68421053e-04,
#           3.94736842e-04,   4.21052632e-04,   4.47368421e-04,
#           4.73684211e-04,   5.00000000e-04]),
#  <a list of 19 Patch objects>)

# %%
normals = para.MeshNormals()
print(np.sum(normals, axis=0)/para.Np)
# Out:
# [  6.79511927e-01   1.18062984e-04  -7.01189320e-01]

# %% [markdown]
# ### setup the timing of the cells
#
# The peak of the wave packet is assumed to start at the origin at t=0.
#
# The start time of the traces is 300 steps before the expected time of arrival which is computed as the z coordinate of the observation point divided by the speed of light. The length is 800 steps what accounts for some propagation lines having greater length.

# %%
# time step
para.dt = 1.0e-13
para.Nt = 800
para.t0 = [p[2]/constants.c -300*para.dt for p in para.pos]
print(np.min(para.t0))
print(np.max(para.t0))
print(len(para.t0))
# Out:
# 3.95788601633e-09
# 4.29126218711e-09
# 230862

# %% [markdown]
# ## check geometry and write to file

# %%
para.ShowMeshedField(showCenters=False,showAxes=True)

# %% [markdown]
# estimated memory requirements

# %%
8*para.Np*para.Nt*6
# Out:
# 8865100800

# %%
filename="Parabola.h5"
para.WriteMeshedField(filename)

# %% [markdown]
# ## load file after propagation and analyze
#
# On my laptop the file is too large to fit into the memory. So I have to load the data
# in chunks and immediately compute the power density I'm interested in. ReadMesh ignores
# the 'ObservationTime' and 'ElMagField' datasets. The former one is loadad by hand
# (code copied from MeshedFields.py). The 'ElMagField' dataset we have to handle slicing it
# trace by trace and computing the trace power density which we then can visualize.

# %%
filename="../run/Parabola.h5"
prop = MeshedField.ReadMesh(filename)

# %%
hdf = h5py.File(filename, "r")
dataset = hdf['ObservationTime']
prop.dt = dataset.attrs.get('dt')
prop.Nt = dataset.attrs.get('Nt')
prop.t0 = np.array(dataset)
hdf.close()

print(np.min(prop.t0))
print(np.max(prop.t0))
print(len(prop.t0))
# Out:
# 3.95788601633e-09
# 4.29126218711e-09
# 230862

# %%
prop.ShowMeshedField(showAxes=True,showGrid=False)

# %%
hdf = h5py.File(filename, "r")
dataset = hdf['ElMagField']
(Np, Nt, Nf) = dataset.shape
print((Np, Nt, Nf))

S_array = []
Pz_array = []
for id in range(Np):
    trace = dataset[id,:,:]
    EVec = trace[:,0:3]
    BVec = trace[:,3:6]
    SVec = np.cross(EVec, BVec) / constants.mu_0
    S = SVec.sum(axis=0)*prop.dt
    S_array.append(np.linalg.norm(S))
    n = prop.MeshNormal(id)
    Pz_array.append(np.dot(S,-n))

hdf.close()
# Out:
# (230862, 800, 6)

# %%
area = prop.MeshArea()
PeakIndex = np.argmax(S_array)
Peak = S_array[PeakIndex]

print("peak energy density = %.6f J/m² at cell %d" % (Peak,PeakIndex))
print("total pulse energy = %.1f µJ" % (1e6*np.dot(area,Pz_array)))

prop.ShowMeshedField(scalars=Pz_array,scalarTitle="Pz",highlight=[PeakIndex],showGrid=False)
# Out:
# peak energy density = 1.879179 J/m² at cell 78525
# total pulse energy = 2313.7 µJ

# %%
hdf = h5py.File(filename, "r")
dataset = hdf['ElMagField']
trace = dataset[PeakIndex,:,:]
hdf.close()

ShowTrace(trace,prop.t0[PeakIndex],prop.dt)

# %%
RightIndex = 39689
LeftIndex = 163552

hdf = h5py.File(filename, "r")
dataset = hdf['ElMagField']
RightTrace = dataset[RightIndex,:,:]
LeftTrace = dataset[LeftIndex,:,:]
hdf.close()

ShowTrace(RightTrace,prop.t0[RightIndex],prop.dt)
ShowTrace(LeftTrace,prop.t0[LeftIndex],prop.dt)

# %% [markdown]
# ## forward propagation from parabola

# %%
filename="../run/ParabolaForward.h5"
prop = MeshedField.ReadMeshedField(filename)

area = prop.MeshArea()
S = [np.linalg.norm(prop.EnergyFlowVector(i)) for i in range(prop.Np)]
Pz = [prop.NormalEnergyFlow(i) for i in range(prop.Np)]

print("peak energy density = %.6f J/m²" % np.max(S))
print("total pulse energy = %.1f µJ" % (1e6*np.dot(area,Pz)))

def pick(id):
    if id>0 and id<prop.Np:
        print("cell No. %d pos=%s" % (id,prop.pos[id]))
        print("pointing vector S=%s" % prop.EnergyFlowVector(id))
        prop.ShowFieldTrace(id)

prop.ShowMeshedField(scalars=Pz,scalarTitle="Pz",pickAction=pick,showGrid=False)
# Out:
# peak energy density = 0.793828 J/m²
# total pulse energy = 2205.4 µJ
# cell No. 121 pos=[ -1.13924626e-03   1.05539316e-03   2.51600000e+00]
# pointing vector S=[ -4.01163791e-02   7.03080682e-04   7.90249169e-01]

# %%
prop.BoundingBox()
# Out:
# ((-0.059999999999999998, 0.059999999999999998),
#  (-0.059999999999999998, 0.059999999999999998),
#  (2.516, 2.516))

# %% [markdown]
# ## left propagation to focus

# %%
mesh = MeshedField.CircularMesh(R=0.003, ratio=1.0, lcar=0.05)
print("%d points" % len(mesh.points))
print("%d triangles" % len(mesh.triangles))
# Out:
# 1780 points
# 3426 triangles

# %%
# shift
d = np.array([0.100, 0.0, 1.258])
# rotate 90° left
pts = [np.array([p[2],p[1],-p[0]])+d for p in mesh.points]
target = MeshedField(pts, mesh.triangles)

normals = target.MeshNormals()
print(np.sum(normals, axis=0)/target.Np)

# time step
target.dt = 1.0e-13
target.Nt = 800
target.t0 = [1.358/constants.c -400*target.dt for p in target.pos]

target.ShowMeshedField(showCenters=False,showAxes=True)
# Out:
# [-1.  0.  0.]

# %%
filename="ParabolaReflectionFocus.h5"
target.WriteMeshedField(filename)

# %%
filename="../run/ParabolaPropagateFocus.h5"
prop = MeshedField.ReadMeshedField(filename)

area = prop.MeshArea()
S = [np.linalg.norm(prop.EnergyFlowVector(i)) for i in range(prop.Np)]
Pz = [prop.NormalEnergyFlow(i) for i in range(prop.Np)]

print("peak energy density = %.6f J/m²" % np.max(S))
print("total pulse energy = %.1f µJ" % (1e6*np.dot(area,Pz)))

def pick(id):
    if id>0 and id<prop.Np:
        print("cell No. %d pos=%s" % (id,prop.pos[id]))
        print("pointing vector S=%s" % prop.EnergyFlowVector(id))
        prop.ShowFieldTrace(id)

prop.ShowMeshedField(scalars=Pz,scalarTitle="Pz",pickAction=pick,showGrid=False)
# Out:
# peak energy density = 0.078833 J/m²
# total pulse energy = 0.2 µJ
# cell No. 2629 pos=[  1.00000000e-01  -4.74208135e-05   1.25713262e+00]
# pointing vector S=[ 0.07861528 -0.00566405  0.00148478]

# %% [markdown]
# ## left reflection to focus

# %%
filename="../run/ParabolaReflectionFocus.h5"
prop = MeshedField.ReadMeshedField(filename)

area = prop.MeshArea()
S = [np.linalg.norm(prop.EnergyFlowVector(i)) for i in range(prop.Np)]
Pz = [prop.NormalEnergyFlow(i) for i in range(prop.Np)]

print("peak energy density = %.6f J/m²" % np.max(S))
print("total pulse energy = %.1f µJ" % (1e6*np.dot(area,Pz)))

def pick(id):
    if id>0 and id<prop.Np:
        print("cell No. %d pos=%s" % (id,prop.pos[id]))
        print("pointing vector S=%s" % prop.EnergyFlowVector(id))
        prop.ShowFieldTrace(id)

prop.ShowMeshedField(scalars=Pz,scalarTitle="Pz",pickAction=pick,showGrid=False)
# Out:
# peak energy density = 606.206366 J/m²
# total pulse energy = 2248.5 µJ
# cell No. 121 pos=[  1.00000000e-01   5.27696580e-05   1.25805696e+00]
# pointing vector S=[ 596.15411061   -2.36801239  -96.80163124]

# %% [markdown]
# ## residual of reflection in forward direction

# %%
filename="../run/ParabolaReflectionForward.h5"
prop = MeshedField.ReadMeshedField(filename)

area = prop.MeshArea()
S = [np.linalg.norm(prop.EnergyFlowVector(i)) for i in range(prop.Np)]
Pz = [prop.NormalEnergyFlow(i) for i in range(prop.Np)]

print("peak energy density = %.6f J/m²" % np.max(S))
print("total pulse energy = %.1f µJ" % (1e6*np.dot(area,Pz)))

def pick(id):
    if id>0 and id<prop.Np:
        print("cell No. %d pos=%s" % (id,prop.pos[id]))
        print("pointing vector S=%s" % prop.EnergyFlowVector(id))
        prop.ShowFieldTrace(id)

prop.ShowMeshedField(scalars=Pz,scalarTitle="Pz",pickAction=pick,showGrid=False)
# Out:
# peak energy density = 0.000157 J/m²
# total pulse energy = 0.1 µJ
# cell No. 1560 pos=[-0.00289296  0.01820601  2.516     ]
# pointing vector S=[ -4.64160677e-06  -5.12808109e-06   1.55402563e-04]
